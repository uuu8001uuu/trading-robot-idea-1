# %%
import pandas as pd
import numpy as np
import sklearn

import yfinance as yf
# import stockstats as st

import matplotlib.pyplot as plt
import seaborn as sns

import random

# %%
data_set = pd.read_csv('data_set.csv', index_col='Date')

# %%
pd.options.display.max_columns = None # show all columns when they are not visible
pd.options.display.max_rows = None # show all rows when they are not visible

# data_set

# %%
# data_set.columns

# %%
pd.options.display.max_columns = None # show all columns when they are not visible
# pd.options.display.max_rows = None # show all rows when they are not visible

# data_set = data_set.round() # round values in DataFrame

# data_set

# %%
# data_set = data_set.dropna()

# data_set = data_set.reset_index()
# columns = ['Date']
# data_set = data_set.drop(columns, axis=1) 

# data_set

# %%
# from sklearn.tree import DecisionTreeRegressor
# data_model = DecisionTreeRegressor(random_state=1)

# # X = data_set.drop('Close', 1)
# X = data_set
# y = data_set['Close']

# data_model.fit(X, y)

# predictions = data_model.predict(X)
# print(predictions)

# %%
# from sklearn.metrics import mean_absolute_error

# predicted_values = data_model.predict(X)
# mean_absolute_error(y, predicted_values)

# %%
# from sklearn.model_selection import train_test_split
# train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# data_model = DecisionTreeRegressor()
# data_model.fit(train_X, train_y)
# val_predictions = data_model.predict(val_X)

# print("First in-sample predictions:", data_model.predict(val_X.head()))
# print("Actual target values for those homes:", y.head().tolist())

# val_mae = mean_absolute_error(val_y, val_predictions)
# print(val_mae)

# %%
# def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
#     model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
#     model.fit(train_X, train_y)
#     preds_val = model.predict(val_X)
#     mae = mean_absolute_error(val_y, preds_val)
#     return(mae)

# candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]
# scores = {leaf_size: get_mae(leaf_size, train_X, val_X, train_y, val_y) for leaf_size in candidate_max_leaf_nodes}
# best_tree_size = min(scores, key=scores.get)
# print(best_tree_size)

# %%
# final_model = DecisionTreeRegressor(max_leaf_nodes=best_tree_size, random_state=1)
# final_model.fit(X, y)

# %%
# from sklearn.model_selection import train_test_split
# train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# final_model = DecisionTreeRegressor()
# final_model.fit(train_X, train_y)
# val_predictions = final_model.predict(val_X)

# print("First in-sample predictions:", data_model.predict(val_X.head()))
# print("Actual target values for those homes:", y.head().tolist())

# val_mae = mean_absolute_error(val_y, val_predictions)
# print(val_mae)

# %%
# from sklearn.model_selection import train_test_split
# pd.options.display.max_columns = None # show all columns when they are not visible

# # Read the data
# X_full = data_set.iloc[:3485,]
# X_test_full = data_set.iloc[3485:,]
# # print(X_full)
# # print('/////////////')
# # print(X_test_full)
# # Получите цель и предикторы
# y = X_full.Close
# # print(y)

# X = X_full.drop('Close', 1).copy()
# # print(X)
# X_test = X_test_full.drop('Close', 1).copy()
# # print(X_test)
# # Отключите набор проверки от данных обучения
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
#                                                       random_state=0)

# %%
# from sklearn.ensemble import RandomForestRegressor

# # Определите модели
# model_1 = RandomForestRegressor(n_estimators=50, random_state=0)
# model_2 = RandomForestRegressor(n_estimators=100, random_state=0)
# model_3 = RandomForestRegressor(n_estimators=100, criterion='mae', random_state=0)
# model_4 = RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0)
# model_5 = RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0)

# models = [model_1, model_2, model_3, model_4, model_5]

# %%
# from sklearn.metrics import mean_absolute_error

# # Функция сравнения разных моделей
# def score_model(model, X_t=X_train, X_v=X_valid, y_t=y_train, y_v=y_valid):
#     model.fit(X_t, y_t)
#     preds = model.predict(X_v)
#     return mean_absolute_error(y_v, preds)

# for i in range(0, len(models)):
#     mae = score_model(models[i])
#     print("Model %d MAE: %d" % (i+1, mae))

# %%
# best_model = model_3
# my_model = model_3

# %%
# my_model.fit(X, y)
# preds_test = my_model.predict(X_test)

# %%
from sklearn.model_selection import train_test_split
pd.options.display.max_columns = None # show all columns when they are not visible

# Read the data
X_full = data_set.iloc[:3485,]
X_test_full = data_set.iloc[3485:,]
# print(X_full)
# print('/////////////')
# print(X_test_full)
# Получите цель и предикторы
y = X_full.Close
# print(y)

X = X_full.drop('Close', 1).copy()
# print(X)
X_test = X_test_full.drop('Close', 1).copy()
# print(X_test)
# Отключите набор проверки от данных обучения
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)
print('X_train', X_train.shape)
print('X_valid', X_valid.shape)
print('y_train', y_train.shape)
print('y_valid', y_valid.shape)

print(y_train.sort_index())
# Out:
# X_train (2788, 34)
# X_valid (697, 34)
# y_train (2788,)
# y_valid (697,)
# Date
# 1993-11-11     27.725245
# 1993-11-16     27.968136
# 1993-11-18     27.743929
# 1993-11-19     27.687878
# 1993-11-22     27.519728
# 1993-11-23     27.669203
# 1993-11-24     27.781286
# 1993-11-29     27.687878
# 1993-11-30     27.706566
# 1993-12-01     27.743929
# 1993-12-02     27.818653
# 1993-12-06     28.024155
# 1993-12-08     28.005491
# 1993-12-09     27.912073
# 1993-12-10     27.856039
# 1993-12-13     28.024155
# 1993-12-16     27.874710
# 1993-12-17     28.027891
# 1993-12-20     28.065517
# 1993-12-21     27.971474
# 1993-12-22     28.159588
# 1993-12-23     28.140778
# 1993-12-28     28.347679
# 1993-12-29     28.310053
# 1993-12-31     28.046713
# 1994-01-03     27.971474
# 1994-01-04     28.084343
# 1994-01-05     28.140778
# 1994-01-06     28.140778
# 1994-01-10     28.648643
# 1994-01-11     28.592218
# 1994-01-12     28.498177
# 1994-01-13     28.422939
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# Определите модели
model_1 = RandomForestRegressor(n_estimators=50, random_state=0)
model_2 = RandomForestRegressor(n_estimators=100, random_state=0)
model_3 = RandomForestRegressor(n_estimators=100, criterion='mae', random_state=0)
model_4 = RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0)
model_5 = RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0)

models = [model_1, model_2, model_3, model_4, model_5]

# %%
from sklearn.metrics import mean_absolute_error

# Функция сравнения разных моделей
def score_model(model, X_t=X_train, X_v=X_valid, y_t=y_train, y_v=y_valid):
    model.fit(X_t, y_t)
    preds = model.predict(X_v)
    return mean_absolute_error(y_v, preds)

for i in range(0, len(models)):
    mae = score_model(models[i])
    print("Model %d MAE: %d" % (i+1, mae))
# Out:
# Model 1 MAE: 0
# Model 2 MAE: 0
# Model 3 MAE: 0
# Model 4 MAE: 0
# Model 5 MAE: 0

# %%
best_model = model_3
my_model = model_3

# %%
my_model.fit(X, y)
preds_test = my_model.predict(X_test)

# %%
print(preds_test)
len(preds_test)
# Out:
# [112.12700508 111.99502243 112.74682838 ... 116.21124298 116.22646576
#  116.22611465]
# 3488

# %%
# z=pd.DataFrame(preds_test)
# print(z)
